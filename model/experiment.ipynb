# %%
import pandas as pd
from time_series_split import split_original_data

# %%
folds = split_original_data()
len(folds)
# Out:
# 3

# %%
folds[0]['train']
# Out:
#             time   ID        pm25        lat         lon  SQRT_SEA_DEM_LAT  \
# 0     2020-01-01   19  116.949130  21.049750  105.741870          5.922647
# 1     2020-01-01   79  105.103043  21.015250  105.800130          4.307231
# 2     2020-01-01  163  118.285100  21.024347  106.017288          4.988467
# 3     2020-01-01  300  116.739130  21.023532  105.853941          4.865087
# 4     2020-01-02   19   76.856667  21.049750  105.741870          5.922647
# ...          ...  ...         ...        ...         ...               ...
# 10188 2021-08-31  159   20.120492  21.037727  106.146807          5.693217
# 10189 2021-08-31  162    7.677892  21.089142  105.990311          5.651733
# 10190 2021-08-31  163   12.976996  21.024347  106.017288          4.988467
# 10191 2021-08-31  195    8.516900  21.338470  105.367300          5.228505
# 10192 2021-08-31  300   23.166667  21.023532  105.853941          4.865087
#
# ...

# %%
folds[0]['validation']
# Out:
#             time   ID       pm25        lat         lon  SQRT_SEA_DEM_LAT  \
# 10193 2021-09-01   51  39.936967  21.200344  105.948544          6.696101
# 10194 2021-09-01   52  31.847583  21.123247  106.288330          5.527568
# 10195 2021-09-01   60  21.877471  21.187340  106.074296          5.014936
# 10196 2021-09-01   62  34.061633  21.151807  106.151880          5.995299
# 10197 2021-09-01   79  30.132174  21.015250  105.800130          4.307231
# ...          ...  ...        ...        ...         ...               ...
# 10554 2021-09-30  162  10.432925  21.089142  105.990311          5.651733
# 10555 2021-09-30  163   8.883363  21.024347  106.017288          4.988467
# 10556 2021-09-30  172   4.259786  20.927000  106.314000          4.784339
# 10557 2021-09-30  195  19.933133  21.338470  105.367300          5.228505
# 10558 2021-09-30  300  35.250000  21.023532  105.853941          4.865087
#
#            WSPD        WDIR        TMP         TX         TN       TP  \
# ...

# %%
folds[0]['test']
# Out:
#             time   ID       pm25        lat         lon  SQRT_SEA_DEM_LAT  \
# 10559 2021-10-01   51  42.399450  21.200344  105.948544          6.696101
# 10560 2021-10-01   52  43.720796  21.123247  106.288330          5.527568
# 10561 2021-10-01   60  26.297608  21.187340  106.074296          5.014936
# 10562 2021-10-01   62  38.715888  21.151807  106.151880          5.995299
# 10563 2021-10-01   79  29.963333  21.015250  105.800130          4.307231
# ...          ...  ...        ...        ...         ...               ...
# 10881 2021-10-31  157   9.786750  21.127740  105.889544          5.476497
# 10882 2021-10-31  158  20.812150  21.156077  106.222311          4.710004
# 10883 2021-10-31  162   4.811000  21.089142  105.990311          5.651733
# 10884 2021-10-31  163   6.359725  21.024347  106.017288          4.988467
# 10885 2021-10-31  300  27.375000  21.023532  105.853941          4.865087
#
#            WSPD        WDIR        TMP         TX         TN      TP  \
# ...
